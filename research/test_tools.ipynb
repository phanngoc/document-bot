# %%
# %pip install langchain_community langchain_openai pymysql

from langchain_community.utilities import SQLDatabase
from sqlalchemy import create_engine
from sqlalchemy.pool import StaticPool

# engine = create_engine(
#     "mysql://",
#     poolclass=StaticPool,
#     connect_args={"check_same_thread": False},
# )

db = SQLDatabase.from_uri("mysql+pymysql://root:root@localhost:13306/eccubedb")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# /Users/ngocp/Documents/projects/document-bot/.venv/lib/python3.12/site-packages/langchain_community/utilities/sql_database.py:123: SAWarning: Did not recognize type 'geometry' of column 'geo'
#   self._metadata.reflect(

# %%
#content/income.sqlite
print(db.dialect)
print(db.get_usable_table_names())
# Out:
# mysql
# ...

# %%
res1 = db.run("SELECT * FROM dtb_order limit 4;")
print(res1)
print(type(res1))
# Out:
# [(2, 6, None, 13, 3, None, 5, 10, '05a1eb5b71cd9e823963dcffe8afa5d99c0e2bd8', '2', None, 'セイ', 'セイ', 'セイ', 'セイ', None, 'duong.thi.diem.huong+100@sun-asterisk.com', '11111111111', '1000004', '東京都', '千代田区大手町次のビルを除く', datetime.datetime(1899, 12, 31, 15, 0), Decimal('298.00'), Decimal('0.00'), Decimal('0.00'), Decimal('0.00'), Decimal('29.00'), Decimal('327.00'), Decimal('327.00'), 'クレジットカード', None, datetime.datetime(2022, 11, 18, 8, 33, 55), datetime.datetime(2022, 11, 18, 8, 42, 37), None, None, 'JPY', None, None, Decimal('0'), Decimal('0'), 8, 'order', 40, 0, 0, '0018', None, '123', None, None, 8, 1, None, 8, None, None, None, None, None, None, None, None, 0, None, None, None, None, None, None, Decimal('0.00'), None, None), (7, 15, None, 40, 2, None, 5, 10, '0a06cc6ae15f0bc3c312b15e585aa6ccaec90400', '7', None, 'セイ', 'セイ', 'セイ', 'セイ', None, 'nguyen.dinh.long+12345@sun-asterisk.com', '07785555545', '8111361', '福岡県', '福岡市南区西長住', datetime.datetime(1916, 2, 3, 15, 0), Decimal('49207.00'),
# ...

# %%
from langchain.chains import create_sql_query_chain
#This chain generates SQL queries for the given databas
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o", temperature=0)
chain = create_sql_query_chain(llm, db)
response = chain.invoke({"question": "How many orders are there"})
response
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[15], line 7
#       5 llm = ChatOpenAI(model="gpt-4o", temperature=0)
#       6 chain = create_sql_query_chain(llm, db)
# ----> 7 response = chain.invoke({"question": "How many orders are there"})
#       8 response
#
# File ~/Documents/projects/document-bot/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:3022, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3020             input = context.run(step.invoke, input, config, **kwargs)
#    3021         else:
# -> 3022             input = context.run(step.invoke, input, config)
#    3023 # finish the root run
#    3024 except BaseException as e:
#
# File ~/Documents/projects/document-bot/.venv/lib/python3.12/site-packages/langchain_core/runnables/base.py:5352, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5346 def invoke(
# ...

# %%
from langchain_community.tools.sql_database.tool import QuerySQLDataBaseTool
